# %% [markdown]
# # Prompt Generator
#
# Colab launcher for [github.com/antopou/prompt-generator](https://github.com/antopou/prompt-generator).

# %%
#@markdown # Clone repository
import os
if not os.path.exists("prompt-generator"):
    # !git clone -q https://github.com/antopou/prompt-generator.git
# %cd prompt-generator

# %%
#@markdown # Install
# !pip install -q .

# %%
#@markdown # Launch web interface
from src import webapp
webapp.run(share=True)
