# %% [markdown]
# # promptgen - Colab Web UI
# This notebook will launch the promptgen Gradio UI directly in Google Colab.

# %%
import os

# If we are running from a freshly opened Colab environment without the files, clone the repo.
# TODO: Replace with your actual GitHub repository URL once you push this.
if not os.path.exists("pyproject.toml"):
    # !git clone https://github.com/antopou/prompt-generator.git
    # %cd prompt-generator

# %%
# Install the promptgen package and its dependencies
# !pip install .

# %%
import promptgen.webapp

# Launch the webapp with a public URL (gradio.live)
promptgen.webapp.run(share=True)
